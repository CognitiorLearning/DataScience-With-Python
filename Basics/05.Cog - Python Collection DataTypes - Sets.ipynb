# %%
my_first_set = {10,2,40,30,20,50,100,100,100,90}

# %%
my_first_set
# Out:
# {2, 10, 20, 30, 40, 50, 90, 100}

# %%
my_first_set[7]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-8ff2e9ff6874> in <module>
# ----> 1 my_first_set[7]
#
# TypeError: 'set' object does not support indexing

# %%
my_first_set.add(5)

# %%
my_first_set
# Out:
# {2, 5, 10, 20, 30, 40, 50, 90, 100}

# %%
my_first_set.update([20,50,70,90,120,120,100])

# %%
my_first_set
# Out:
# {2, 5, 10, 20, 30, 40, 50, 70, 90, 100, 120}

# %%
my_first_set.discard(40)

# %%
my_first_set
# Out:
# {2, 5, 10, 20, 30, 50, 70, 90, 100, 120}

# %%
my_first_set.clear()

# %%
my_first_set
# Out:
# set()

# %%
del my_first_set

# %%
my_first_set
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-400b2b7ccb7b> in <module>
# ----> 1 my_first_set
#
# NameError: name 'my_first_set' is not defined
