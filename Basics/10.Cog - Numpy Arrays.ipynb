# %%
mylist1 = [1,2,3,4,5]
mylist2=[2,3,4,5,6]

# %%
mylist1/mylist2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-43b21001d9ce> in <module>
# ----> 1 mylist1/mylist2
#
# TypeError: unsupported operand type(s) for /: 'list' and 'list'

# %%
sales=[2345, 3775,5676,3345]
profit=[325,445,445,333]

# %%
profit/sales
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-6764e8c1a10d> in <module>
# ----> 1 profit/sales
#
# TypeError: unsupported operand type(s) for /: 'list' and 'list'

# %%
import numpy as np

# %%
sales_array=np.array(sales)

# %%
sales_array
# Out:
# array([2345, 3775, 5676, 3345])

# %%
profit_array=np.array(profit)

# %%
profit_array
# Out:
# array([325, 445, 445, 333])

# %%
profit_array/sales_array
# Out:
# array([0.13859275, 0.11788079, 0.07840028, 0.09955157])

# %%
sales*2
# Out:
# [2345, 3775, 5676, 3345, 2345, 3775, 5676, 3345]

# %%
sales_array*2
# Out:
# array([ 4690,  7550, 11352,  6690])

# %%
sales[0]=0

# %%
sales
# Out:
# [0, 3775, 5676, 3345]

# %%
sales_array[0]=0

# %%
sales_array
# Out:
# array([   0, 3775, 5676, 3345])

# %%
sales_1=sales[0:2]

# %%
sales_1
# Out:
# [0, 3775]

# %%
sales_1[0]=1000

# %%
sales_1
# Out:
# [1000, 3775]

# %%
sales
# Out:
# [0, 3775, 5676, 3345]

# %%
sales_array_1=sales_array[0:2]

# %%
sales_array_1
# Out:
# array([   0, 3775])

# %%
sales_array_1[0]=1000

# %%
sales_array_1
# Out:
# array([1000, 3775])

# %%
sales_array
# Out:
# array([1000, 3775, 5676, 3345])

# %%
sales_array_2=sales_array.copy()

# %%
sales_array_2
# Out:
# array([1000, 3775, 5676, 3345])

# %%
sales_array_2[0]=0

# %%
sales_array_2
# Out:
# array([   0, 3775, 5676, 3345])

# %%
sales_array
# Out:
# array([1000, 3775, 5676, 3345])

# %%
list1=[1,2,3,4,5,'R']

# %%
list1
# Out:
# [1, 2, 3, 4, 5, 'R']

# %%
array_1=np.array(list1)

# %%
array_1
# Out:
# array(['1', '2', '3', '4', '5', 'R'], dtype='<U11')

# %%
tuple_1=(1,2,3,4,'R')

# %%
tuple_1
# Out:
# (1, 2, 3, 4, 'R')

# %%
array_1
# Out:
# array(['1', '2', '3', '4', '5', 'R'], dtype='<U11')
