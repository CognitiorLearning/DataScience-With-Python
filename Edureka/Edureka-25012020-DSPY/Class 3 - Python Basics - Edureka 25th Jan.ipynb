# %%
#Functions with Date Paramter 
#DOJ
#Age

# %%
#DataFrames
#User Defined Function
#Dfly

# %%
import os
os.chdir('D:\\D\\Edureka\\Edureka - 24 June - Python\\Class 5\\')

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('DemographicData.csv')

# %%
len(dataset)
# Out:
# 195

# %%
dataset.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
len(dataset.columns)
# Out:
# 5

# %%
dataset.head(1)
# Out:
#   Country Name Country Code  Birth rate  Internet users Income Group
# 0        Aruba          ABW      10.244            78.9  High income

# %%
dataset.tail(2)
# Out:
#     Country Name Country Code  Birth rate  Internet users         Income Group
# 193       Zambia          ZMB      40.471            15.4  Lower middle income
# 194     Zimbabwe          ZWE      35.715            18.5           Low income

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
dataset.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
dataset.columns = ['CountryName','CountryCode','BirthRate','InternetUsers','IncomeGroup']

# %%
dataset = dataset.rename(columns={'CountryName':'CN', 'BirthRate':'BR'})

# %%
dataset.rename(columns={'CN':'CountryName','BR':'BirthRate'},inplace=True)

# %%
dataset
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
dataset[1:4][['CountryName','BirthRate']]
# Out:
#    CountryName  BirthRate
# 1  Afghanistan     35.253
# 2       Angola     45.985
# 3      Albania     12.877

# %%
dataset[(dataset['CountryName']=='India') | (dataset['CountryName']=='Pakistan')]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 80        India         IND     20.291           15.1  Lower middle income
# 135    Pakistan         PAK     29.582           10.9  Lower middle income

# %%
dataset[dataset['CountryName'].isin(['India','Pakistan'])]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 80        India         IND     20.291           15.1  Lower middle income
# 135    Pakistan         PAK     29.582           10.9  Lower middle income

# %%
dataset['MyCalc'] = dataset.BirthRate * dataset.InternetUsers

# %%
dataset
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup    MyCalc
# 0            High income  808.2516
# 1             Low income  207.9927
# 2    Upper middle income  878.3135
# 3    Upper middle income  736.5644
# ...

# %%
dataset.sort_values(['MyCalc'],ascending=1)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 117             Myanmar         MMR     18.119           1.60
# 52              Eritrea         ERI     34.800           0.90
# 172         Timor-Leste         TLS     35.755           1.10
# 11              Burundi         BDI     44.151           1.30
# 64               Guinea         GIN     37.337           1.60
# ..                  ...         ...        ...            ...
# 91                Kenya         KEN     35.194          39.00
# 188  West Bank and Gaza         PSE     30.394          46.60
# 85               Israel         ISR     21.300          70.80
# 128             Nigeria         NGA     40.045          38.00
# 96               Kuwait         KWT     20.575          75.46
#
#              IncomeGroup     MyCalc
# 117  Lower middle income    28.9904
# 52            Low income    31.3200
# 172  Lower middle income    39.3305
# 11            Low income    57.3963
# ...

# %%
dataset.drop('MyCalc',axis=1,inplace=True)

# %%
dataset.InternetUsers<2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
dataset.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
dataset.groupby(['IncomeGroup']).size()
# Out:
# IncomeGroup
# High income            67
# Low income             30
# Lower middle income    50
# Upper middle income    48
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lmplot(data=dataset, x='InternetUsers',y='BirthRate',fit_reg=False,hue='IncomeGroup')

# %%
df1 = pd.DataFrame(np.array([['a',5,9],['b',4,61],['c',24,9]]), columns=['name','attr1','attr2'])

# %%
df1
# Out:
#   name attr1 attr2
# 0    a     5     9
# 1    b     4    61
# 2    c    24     9

# %%
df2 = pd.DataFrame(np.array([['a',5,19],['b',4,16],['c',2,9]]), columns=['name','attr1','attr2'])

# %%
df2
# Out:
#   name attr1 attr2
# 0    a     5    19
# 1    b     4    16
# 2    c     2     9

# %%
df3 = pd.DataFrame(np.array([['a',5,19],['b',4,16],['e',2,9]]), columns=['name','attr1','attr2'])

# %%
df1
# Out:
#   name attr1 attr2
# 0    a     5     9
# 1    b     4    61
# 2    c    24     9

# %%
df2
# Out:
#   name attr1 attr2
# 0    a     5    19
# 1    b     4    16
# 2    c     2     9

# %%
df3
# Out:
#   name attr1 attr2
# 0    a     5    19
# 1    b     4    16
# 2    e     2     9

# %%
pd.merge(pd.merge(df1,df2,on='name'),df3,on='name')
# Out:
#   name attr1_x attr2_x attr1_y attr2_y attr1 attr2
# 0    a       5       9       5      19     5    19
# 1    b       4      61       4      16     4    16

# %%
df1.merge(df2,on='name').merge(df3,on='name')
# Out:
#   name attr1_x attr2_x attr1_y attr2_y attr1 attr2
# 0    a       5       9       5      19     5    19
# 1    b       4      61       4      16     4    16

# %%
pd.merge(pd.merge(df1,df2,how='left',left_on=['name','attr1']),df3, right_on=['name','attr1'])
# Out:
#   name attr1 attr2_x attr2_y attr2
# 0    a     5       9      19    19
# 1    b     4      61      16    16

# %%
df1
# Out:
#   name attr1 attr2
# 0    a     5     9
# 1    b     4    61
# 2    c    24     9

# %%
df2
# Out:
#   name attr1 attr2
# 0    a     5    19
# 1    b     4    16
# 2    c     2     9

# %%
pd.concat([df1,df2],axis=0)
# Out:
#   name attr1 attr2
# 0    a     5     9
# 1    b     4    61
# 2    c    24     9
# 0    a     5    19
# 1    b     4    16
# 2    c     2     9

# %%
def revenue():
    new_rev = 100*150
    print(new_rev)

# %%
revenue()
# Out:
# 15000

# %%
def revenue(cust):
    new_rev = cust*150
    print(new_rev)

# %%
revenue('a')
# Out:
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa

# %%
def revenue(cust,price):
    new_rev = cust*price
    print(new_rev)

# %%
revenue(150,25)
# Out:
# 3750

# %%
def revenue(cust, price=100):
    new_rev = cust*price
    print(new_rev)

# %%
a=revenue(20)
# Out:
# 2000

# %%
a

# %%
def revenue(cust, price=100):
    new_rev = cust*price
    return new_rev

# %%
a=revenue(10,15)

# %%
a
# Out:
# 150

# %%
int(input('cust'))
# Out:
# cust10
# 10

# %%
def financial(revenue,expense):
    """This function helps me to find the profit and profit ratio"""
    profit = revenue-expense
    profitratio = profit/revenue
    print(profit,profitratio)
    #print(profitratio)

# %%
financial(1000,100)
# Out:
# 900 0.9

# %%
def financial(revenue,expense):
    """This function helps me to find the profit and profit ratio"""
    profit = revenue-expense
    profitratio = profit/revenue
    return (profit,profitratio)
    #print(profitratio)

# %%
financial(1000,100)
# Out:
# (900, 0.9)

# %%
def financial(revenue,expense):
    """This function helps me to find the profit and profit ratio"""
    profit = revenue-expense
    profitratio = profit/revenue
    return ({'Profit': profit, 'Profitratio':profitratio})
    #print(profitratio)

# %%
a=financial(1000,100)

# %%
a
# Out:
# {'Profit': 900, 'Profitratio': 0.9}

# %%
def convertctof(temp):
    f = (temp*9/5)+32
    return f

# %%
convertctof(38)
# Out:
# 100.4

# %%
ctof_lm = lambda c: 9/5*c+32

# %%
ctof_lm(38)
# Out:
# 100.4

# %%
def multiply(x,y):
    z=x*y
    print(z)

# %%
multiply(10,1)
# Out:
# 10

# %%
muliply_lam = lambda x,y:  x*y

# %%
muliply_lam(10,1)
# Out:
# 10

# %%
some_num = [2,4,6,8]

# %%
[4,4,6,8]

# %%
[4,8,6,8]

# %%
[4,8,12,8]

# %%
[4,8,12,16]

# %%
double = map(lambda x : x+x, some_num)

# %%
tuple(double)
# Out:
# (4, 8, 12, 16)

# %%
string = ['My','Python']

# %%
cap = map(lambda x: str.upper(x), string)

# %%
list(cap)
# Out:
# ['MY', 'PYTHON']

# %%
cap

# %%
age = [34,33,32,21,22,25]

# %%
list(filter(lambda x : x>25, age))
# Out:
# [34, 33, 32]

# %%
countries = ['India', 'USA', 'UAE', 'France']

# %%
list(filter(lambda x : (x=='UAE') | (x=='India'), countries))
# Out:
# ['India', 'UAE']

# %%
list(filter(lambda x : (len(x)>3) & (x=='India'), countries))
# Out:
# ['India']

# %%
import os
os.chdir('C:\\Users\\Admin\\Downloads\\flight_data\\')

# %%
flight_data = pd.read_csv('flight_data.csv')

# %%
flight_data
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
# !pip install dfply

# %%
len(flight_data)
# Out:
# 336776

# %%
from dfply import *

# %%
flight_data
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
(flight_data >>
select(X.origin, X.dest, X.hour)>>
head())
# Out:
#   origin dest  hour
# 0    EWR  IAH     5
# 1    LGA  IAH     5
# 2    JFK  MIA     5
# 3    JFK  BQN     5
# 4    LGA  ATL     6

# %%
(flight_data >>
select(~X.origin, ~X.dest, ~X.hour)>>
head())
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum  air_time  distance  \
# 0             819       11.0      UA    1545  N14228     227.0      1400
# 1             830       20.0      UA    1714  N24211     227.0      1416
# 2             850       33.0      AA    1141  N619AA     160.0      1089
# 3            1022      -18.0      B6     725  N804JB     183.0      1576
# 4             837      -25.0      DL     461  N668DN     116.0       762
#
#    minute      time_hour
# 0      15  1/1/2013 5:00
# 1      29  1/1/2013 5:00
# 2      40  1/1/2013 5:00
# ...

# %%
(flight_data >>
mask(X.month==1, X.day==1, X.origin=='JFK', X.hour>10)>>
head())
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 151  2013      1    1     848.0            1835      853.0    1001.0
# 258  2013      1    1    1059.0            1100       -1.0    1210.0
# 265  2013      1    1    1111.0            1115       -4.0    1222.0
# 266  2013      1    1    1112.0            1100       12.0    1440.0
# 272  2013      1    1    1124.0            1100       24.0    1435.0
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 151            1950      851.0      MQ    3944  N942MQ    JFK  BWI      41.0
# 258            1215       -5.0      MQ    3792  N509MQ    JFK  DCA      50.0
# 265            1226       -4.0      B6      24  N279JB    JFK  BTV      52.0
# 266            1438        2.0      UA     285  N517UA    JFK  SFO     364.0
# 272            1431        4.0      B6     641  N590JB    JFK  SFO     349.0
#
#      distance  hour  minute       time_hour
# ...

# %%
(flight_data >>
arrange(X.distance, X.hour, ascending=True))
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 275945  2013      7   27       NaN             106        NaN       NaN
# 3083    2013      1    4    1240.0            1200       40.0    1333.0
# 3901    2013      1    5    1155.0            1200       -5.0    1241.0
# 3426    2013      1    4    1829.0            1615      134.0    1937.0
# 10235   2013      1   12    1613.0            1617       -4.0    1708.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 331506  2013      9   25    1001.0            1000        1.0    1508.0
# 333478  2013      9   27     951.0            1000       -9.0    1442.0
# 334406  2013      9   28     955.0            1000       -5.0    1412.0
# 335095  2013      9   29     957.0            1000       -3.0    1405.0
# 336081  2013      9   30     959.0            1000       -1.0    1438.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
(flight_data >>
mutate(new_distance = X.distance/1000, carrier_origin = X.carrier + X.origin))
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  ...  tailnum origin dest air_time  \
# ...

# %%
(flight_data >>
group_by(X.origin) >>
summarise(mean_distance = X.distance.mean()))
# Out:
#   origin  mean_distance
# 0    EWR    1056.742790
# 1    JFK    1266.249077
# 2    LGA     779.835671

# %%
flight_data.loc[flight_data['hour']>10, 'speed'] = flight_data['distance']/(flight_data['air_time']*60)
result = flight_data.groupby('origin', as_index=False)['speed'].mean()
result.sort_values('speed', ascending=False)
# Out:
#   origin     speed
# 0    EWR  0.109777
# 1    JFK  0.109427
# 2    LGA  0.107362

# %%
(flight_data >>
mask(X.hour>10) >>
mutate(speed = X.distance/(X.air_time*60))>>
group_by(X.origin)>>
summarise(mean_speed=X.speed.mean())>>
arrange(X.mean_speed, ascending = False))
# Out:
#   origin  mean_speed
# 0    EWR    0.109777
# 1    JFK    0.109427
# 2    LGA    0.107362

# %%
#Create a DataFrame
df1 = {
    'Subject':['semester1','semester2','semester3','semester4','semester1',
               'semester2','semester3'],
   'Score':[62,47,55,74,31,77,85]}
 
df2 = {
    'Subject':['semester1','semester2','semester3','semester4'],
   'Score':[90,47,85,74]}
 
 
df1 = pd.DataFrame(df1,columns=['Subject','Score'])
df2 = pd.DataFrame(df2,columns=['Subject','Score'])

# %%
df1
# Out:
#      Subject  Score
# 0  semester1     62
# 1  semester2     47
# 2  semester3     55
# 3  semester4     74
# 4  semester1     31
# 5  semester2     77
# 6  semester3     85

# %%
df2
# Out:
#      Subject  Score
# 0  semester1     90
# 1  semester2     47
# 2  semester3     85
# 3  semester4     74

# %%
df_union_all = pd.concat([df1,df2])

# %%
df_union_all
# Out:
#      Subject  Score
# 0  semester1     62
# 1  semester2     47
# 2  semester3     55
# 3  semester4     74
# 4  semester1     31
# 5  semester2     77
# 6  semester3     85
# 0  semester1     90
# 1  semester2     47
# 2  semester3     85
# 3  semester4     74

# %%
df_union = pd.concat([df1, df2]).drop_duplicates().reset_index()

# %%
df_union
# Out:
#    index    Subject  Score
# 0      0  semester1     62
# 1      1  semester2     47
# 2      2  semester3     55
# 3      3  semester4     74
# 4      4  semester1     31
# 5      5  semester2     77
# 6      6  semester3     85
# 7      0  semester1     90
