# %% [markdown]
# # Minus in Python DataFrame

# %%
import pandas as pd

# %%
df1 = pd.DataFrame([[1,'a'],[2,'b']], columns=['ID','Names'])

# %%
df1
# Out:
#    ID Names
# 0   1     a
# 1   2     b

# %%
df2 = pd.DataFrame([[1,'a']],columns=['ID', 'Names'])
df1 = pd.DataFrame([[1,'a']], columns=['ID','Names'])

# %%
df2
# Out:
#    ID Names
# 0   1     a

# %%
df2 = pd.DataFrame([[1,'a']],columns=['ID', 'Names'])

# %%
df1.equals(df2)
# Out:
# True

# %%
df1[df1.ID.isin(df2.ID) == False]
# Out:
#    ID Names
# 1   2     b

# %%
# !pip install dfply
# Out:
# Collecting dfply
#   Downloading https://files.pythonhosted.org/packages/53/91/18ab48c64661252dadff685f8ddbc6f456302923918f488714ee2345d49b/dfply-0.3.3-py3-none-any.whl (612kB)
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (from dfply) (0.23.4)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from dfply) (1.16.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas->dfply) (2.7.5)
# Requirement already satisfied: pytz>=2011k in c:\users\hp\anaconda3\lib\site-packages (from pandas->dfply) (2018.9)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.5.0->pandas->dfply) (1.12.0)
# Installing collected packages: dfply
# Successfully installed dfply-0.3.3
# You are using pip version 18.1, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from dfply import *
import pandas as pd
import numpy as np

# %%
import os
os.chdir('C:\\Users\\HP\\Desktop\\')
flight_data = pd.read_csv('nycflights13.csv')
flight_data.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute            time_hour
# 0      1400     5      15  2013-01-01 05:00:00
# 1      1416     5      29  2013-01-01 05:00:00
# 2      1089     5      40  2013-01-01 05:00:00
# 3      1576     5      45  2013-01-01 05:00:00
# 4       762     6       0  2013-01-01 06:00:00

# %%
(flight_data >>
 select(X.origin, X.dest, X.hour) >>
 head()
)
# Out:
#   origin dest  hour
# 0    EWR  IAH     5
# 1    LGA  IAH     5
# 2    JFK  MIA     5
# 3    JFK  BQN     5
# 4    LGA  ATL     6

# %%
(flight_data >>
 drop(X.year, X.month, X.day) >>
 head()
)
# Out:
#    dep_time  sched_dep_time  dep_delay  arr_time  sched_arr_time  arr_delay  \
# 0     517.0             515        2.0     830.0             819       11.0
# 1     533.0             529        4.0     850.0             830       20.0
# 2     542.0             540        2.0     923.0             850       33.0
# 3     544.0             545       -1.0    1004.0            1022      -18.0
# 4     554.0             600       -6.0     812.0             837      -25.0
#
#   carrier  flight tailnum origin dest  air_time  distance  hour  minute  \
# 0      UA    1545  N14228    EWR  IAH     227.0      1400     5      15
# 1      UA    1714  N24211    LGA  IAH     227.0      1416     5      29
# 2      AA    1141  N619AA    JFK  MIA     160.0      1089     5      40
# 3      B6     725  N804JB    JFK  BQN     183.0      1576     5      45
# 4      DL     461  N668DN    LGA  ATL     116.0       762     6       0
#
#              time_hour
# 0  2013-01-01 05:00:00
# 1  2013-01-01 05:00:00
# 2  2013-01-01 05:00:00
# 3  2013-01-01 05:00:00
# 4  2013-01-01 06:00:00

# %%
(flight_data >>
 select(~X.hour, ~X.minute)
)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# 5       2013      1    1     554.0             558       -4.0     740.0
# 6       2013      1    1     555.0             600       -5.0     913.0
# 7       2013      1    1     557.0             600       -3.0     709.0
# 8       2013      1    1     557.0             600       -3.0     838.0
# 9       2013      1    1     558.0             600       -2.0     753.0
# 10      2013      1    1     558.0             600       -2.0     849.0
# 11      2013      1    1     558.0             600       -2.0     853.0
# 12      2013      1    1     558.0             600       -2.0     924.0
# 13      2013      1    1     558.0             600       -2.0     923.0
# 14      2013      1    1     559.0             600       -1.0     941.0
# 15      2013      1    1     559.0             559        0.0     702.0
# 16      2013      1    1     559.0             600       -1.0     854.0
# 17      2013      1    1     600.0             600        0.0     851.0
# 18      2013      1    1     600.0             600        0.0     837.0
# 19      2013      1    1     601.0             600        1.0     844.0
# 20      2013      1    1     602.0             610       -8.0     812.0
# 21      2013      1    1     602.0             605       -3.0     821.0
# 22      2013      1    1     606.0             610       -4.0     858.0
# 23      2013      1    1     606.0             610       -4.0     837.0
# 24      2013      1    1     607.0             607        0.0     858.0
# 25      2013      1    1     608.0             600        8.0     807.0
# 26      2013      1    1     611.0             600       11.0     945.0
# 27      2013      1    1     613.0             610        3.0     925.0
# 28      2013      1    1     615.0             615        0.0    1039.0
# 29      2013      1    1     615.0             615        0.0     833.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336746  2013      9   30    2123.0            2125       -2.0    2223.0
# 336747  2013      9   30    2127.0            2129       -2.0    2314.0
# 336748  2013      9   30    2128.0            2130       -2.0    2328.0
# 336749  2013      9   30    2129.0            2059       30.0    2230.0
# 336750  2013      9   30    2131.0            2140       -9.0    2225.0
# 336751  2013      9   30    2140.0            2140        0.0      10.0
# 336752  2013      9   30    2142.0            2129       13.0    2250.0
# 336753  2013      9   30    2145.0            2145        0.0     115.0
# 336754  2013      9   30    2147.0            2137       10.0      30.0
# 336755  2013      9   30    2149.0            2156       -7.0    2245.0
# 336756  2013      9   30    2150.0            2159       -9.0    2250.0
# 336757  2013      9   30    2159.0            1845      194.0    2344.0
# 336758  2013      9   30    2203.0            2205       -2.0    2339.0
# 336759  2013      9   30    2207.0            2140       27.0    2257.0
# 336760  2013      9   30    2211.0            2059       72.0    2339.0
# 336761  2013      9   30    2231.0            2245      -14.0    2335.0
# 336762  2013      9   30    2233.0            2113       80.0     112.0
# 336763  2013      9   30    2235.0            2001      154.0      59.0
# 336764  2013      9   30    2237.0            2245       -8.0    2345.0
# 336765  2013      9   30    2240.0            2245       -5.0    2334.0
# 336766  2013      9   30    2240.0            2250      -10.0    2347.0
# 336767  2013      9   30    2241.0            2246       -5.0    2345.0
# 336768  2013      9   30    2307.0            2255       12.0    2359.0
# 336769  2013      9   30    2349.0            2359      -10.0     325.0
# 336770  2013      9   30       NaN            1842        NaN       NaN
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819       11.0      UA    1545  N14228    EWR  IAH
# 1                  830       20.0      UA    1714  N24211    LGA  IAH
# 2                  850       33.0      AA    1141  N619AA    JFK  MIA
# 3                 1022      -18.0      B6     725  N804JB    JFK  BQN
# 4                  837      -25.0      DL     461  N668DN    LGA  ATL
# 5                  728       12.0      UA    1696  N39463    EWR  ORD
# 6                  854       19.0      B6     507  N516JB    EWR  FLL
# 7                  723      -14.0      EV    5708  N829AS    LGA  IAD
# 8                  846       -8.0      B6      79  N593JB    JFK  MCO
# 9                  745        8.0      AA     301  N3ALAA    LGA  ORD
# 10                 851       -2.0      B6      49  N793JB    JFK  PBI
# 11                 856       -3.0      B6      71  N657JB    JFK  TPA
# 12                 917        7.0      UA     194  N29129    JFK  LAX
# 13                 937      -14.0      UA    1124  N53441    EWR  SFO
# 14                 910       31.0      AA     707  N3DUAA    LGA  DFW
# 15                 706       -4.0      B6    1806  N708JB    JFK  BOS
# 16                 902       -8.0      UA    1187  N76515    EWR  LAS
# 17                 858       -7.0      B6     371  N595JB    LGA  FLL
# 18                 825       12.0      MQ    4650  N542MQ    LGA  ATL
# 19                 850       -6.0      B6     343  N644JB    EWR  PBI
# 20                 820       -8.0      DL    1919  N971DL    LGA  MSP
# 21                 805       16.0      MQ    4401  N730MQ    LGA  DTW
# 22                 910      -12.0      AA    1895  N633AA    EWR  MIA
# 23                 845       -8.0      DL    1743  N3739P    JFK  ATL
# 24                 915      -17.0      UA    1077  N53442    EWR  MIA
# 25                 735       32.0      MQ    3768  N9EAMQ    EWR  ORD
# 26                 931       14.0      UA     303  N532UA    JFK  SFO
# 27                 921        4.0      B6     135  N635JB    JFK  RSW
# 28                1100      -21.0      B6     709  N794JB    JFK  SJU
# 29                 842       -9.0      DL     575  N326NB    EWR  ATL
# ...                ...        ...     ...     ...     ...    ...  ...
# 336746            2247      -24.0      EV    5489  N712EV    LGA  CHO
# 336747            2323       -9.0      EV    3833  N16546    EWR  CLT
# 336748            2359      -31.0      B6      97  N807JB    JFK  DEN
# 336749            2232       -2.0      EV    5048  N751EV    LGA  RIC
# 336750            2255      -30.0      MQ    3621  N807MQ    JFK  DCA
# 336751              40      -30.0      AA     185  N335AA    JFK  LAX
# 336752            2239       11.0      EV    4509  N12957    EWR  PWM
# 336753             140      -25.0      B6    1103  N633JB    JFK  SJU
# 336754              27        3.0      B6    1371  N627JB    LGA  FLL
# 336755            2308      -23.0      UA     523  N813UA    EWR  BOS
# 336756            2306      -16.0      EV    3842  N10575    EWR  MHT
# 336757            2030      194.0      9E    3320  N906XJ    JFK  BUF
# 336758            2331        8.0      EV    5311  N722EV    LGA  BGR
# 336759            2250        7.0      MQ    3660  N532MQ    LGA  BNA
# 336760            2242       57.0      EV    4672  N12145    EWR  STL
# 336761            2356      -21.0      B6     108  N193JB    JFK  PWM
# 336762              30       42.0      UA     471  N578UA    EWR  SFO
# 336763            2249      130.0      B6    1083  N804JB    JFK  MCO
# 336764            2353       -8.0      B6     234  N318JB    JFK  BTV
# 336765            2351      -17.0      B6    1816  N354JB    JFK  SYR
# 336766               7      -20.0      B6    2002  N281JB    JFK  BUF
# 336767               1      -16.0      B6     486  N346JB    JFK  ROC
# 336768            2358        1.0      B6     718  N565JB    JFK  BOS
# 336769             350      -25.0      B6     745  N516JB    JFK  PSE
# 336770            2019        NaN      EV    5274  N740EV    LGA  BNA
# 336771            1634        NaN      9E    3393     NaN    JFK  DCA
# 336772            2312        NaN      9E    3525     NaN    LGA  SYR
# 336773            1330        NaN      MQ    3461  N535MQ    LGA  BNA
# 336774            1344        NaN      MQ    3572  N511MQ    LGA  CLE
# 336775            1020        NaN      MQ    3531  N839MQ    LGA  RDU
#
#         air_time  distance            time_hour
# 0          227.0      1400  2013-01-01 05:00:00
# 1          227.0      1416  2013-01-01 05:00:00
# 2          160.0      1089  2013-01-01 05:00:00
# 3          183.0      1576  2013-01-01 05:00:00
# 4          116.0       762  2013-01-01 06:00:00
# 5          150.0       719  2013-01-01 05:00:00
# 6          158.0      1065  2013-01-01 06:00:00
# 7           53.0       229  2013-01-01 06:00:00
# 8          140.0       944  2013-01-01 06:00:00
# 9          138.0       733  2013-01-01 06:00:00
# 10         149.0      1028  2013-01-01 06:00:00
# 11         158.0      1005  2013-01-01 06:00:00
# 12         345.0      2475  2013-01-01 06:00:00
# 13         361.0      2565  2013-01-01 06:00:00
# 14         257.0      1389  2013-01-01 06:00:00
# 15          44.0       187  2013-01-01 05:00:00
# 16         337.0      2227  2013-01-01 06:00:00
# 17         152.0      1076  2013-01-01 06:00:00
# 18         134.0       762  2013-01-01 06:00:00
# 19         147.0      1023  2013-01-01 06:00:00
# 20         170.0      1020  2013-01-01 06:00:00
# 21         105.0       502  2013-01-01 06:00:00
# 22         152.0      1085  2013-01-01 06:00:00
# 23         128.0       760  2013-01-01 06:00:00
# 24         157.0      1085  2013-01-01 06:00:00
# 25         139.0       719  2013-01-01 06:00:00
# 26         366.0      2586  2013-01-01 06:00:00
# 27         175.0      1074  2013-01-01 06:00:00
# 28         182.0      1598  2013-01-01 06:00:00
# 29         120.0       746  2013-01-01 06:00:00
# ...          ...       ...                  ...
# 336746      45.0       305  2013-09-30 21:00:00
# 336747      72.0       529  2013-09-30 21:00:00
# 336748     213.0      1626  2013-09-30 21:00:00
# 336749      45.0       292  2013-09-30 20:00:00
# 336750      36.0       213  2013-09-30 21:00:00
# 336751     298.0      2475  2013-09-30 21:00:00
# 336752      47.0       284  2013-09-30 21:00:00
# 336753     192.0      1598  2013-09-30 21:00:00
# 336754     139.0      1076  2013-09-30 21:00:00
# 336755      37.0       200  2013-09-30 21:00:00
# 336756      39.0       209  2013-09-30 21:00:00
# 336757      50.0       301  2013-09-30 18:00:00
# 336758      61.0       378  2013-09-30 22:00:00
# 336759      97.0       764  2013-09-30 21:00:00
# 336760     120.0       872  2013-09-30 20:00:00
# 336761      48.0       273  2013-09-30 22:00:00
# 336762     318.0      2565  2013-09-30 21:00:00
# 336763     123.0       944  2013-09-30 20:00:00
# 336764      43.0       266  2013-09-30 22:00:00
# 336765      41.0       209  2013-09-30 22:00:00
# 336766      52.0       301  2013-09-30 22:00:00
# 336767      47.0       264  2013-09-30 22:00:00
# 336768      33.0       187  2013-09-30 22:00:00
# 336769     196.0      1617  2013-09-30 23:00:00
# 336770       NaN       764  2013-09-30 18:00:00
# 336771       NaN       213  2013-09-30 14:00:00
# 336772       NaN       198  2013-09-30 22:00:00
# 336773       NaN       764  2013-09-30 12:00:00
# 336774       NaN       419  2013-09-30 11:00:00
# 336775       NaN       431  2013-09-30 08:00:00
#
# [336776 rows x 17 columns]

# %%
(flight_data >> 
     mask(X.month == 1, X.day == 1, X.origin == 'JFK', X.hour > 10) >>
     head())
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 151  2013      1    1     848.0            1835      853.0    1001.0
# 258  2013      1    1    1059.0            1100       -1.0    1210.0
# 265  2013      1    1    1111.0            1115       -4.0    1222.0
# 266  2013      1    1    1112.0            1100       12.0    1440.0
# 272  2013      1    1    1124.0            1100       24.0    1435.0
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 151            1950      851.0      MQ    3944  N942MQ    JFK  BWI      41.0
# 258            1215       -5.0      MQ    3792  N509MQ    JFK  DCA      50.0
# 265            1226       -4.0      B6      24  N279JB    JFK  BTV      52.0
# 266            1438        2.0      UA     285  N517UA    JFK  SFO     364.0
# 272            1431        4.0      B6     641  N590JB    JFK  SFO     349.0
#
#      distance  hour  minute            time_hour
# 151       184    18      35  2013-01-01 18:00:00
# 258       213    11       0  2013-01-01 11:00:00
# 265       266    11      15  2013-01-01 11:00:00
# 266      2586    11       0  2013-01-01 11:00:00
# 272      2586    11       0  2013-01-01 11:00:00

# %%
(flight_data >>
 arrange(X.distance, X.hour) >>
 head()
)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 275945  2013      7   27       NaN             106        NaN       NaN
# 3083    2013      1    4    1240.0            1200       40.0    1333.0
# 3901    2013      1    5    1155.0            1200       -5.0    1241.0
# 3426    2013      1    4    1829.0            1615      134.0    1937.0
# 10235   2013      1   12    1613.0            1617       -4.0    1708.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 275945             245        NaN      US    1632     NaN    EWR  LGA
# 3083              1306       27.0      EV    4193  N14972    EWR  PHL
# 3901              1306      -25.0      EV    4193  N14902    EWR  PHL
# 3426              1721      136.0      EV    4502  N15983    EWR  PHL
# 10235             1722      -14.0      EV    4616  N11150    EWR  PHL
#
#         air_time  distance  hour  minute            time_hour
# 275945       NaN        17     1       6  2013-07-27 01:00:00
# 3083        30.0        80    12       0  2013-01-04 12:00:00
# 3901        29.0        80    12       0  2013-01-05 12:00:00
# 3426        28.0        80    16      15  2013-01-04 16:00:00
# 10235       36.0        80    16      17  2013-01-12 16:00:00

# %%
(flight_data >>
 arrange(X.distance, X.hour, ascending=False) >>
 head()
)
# Out:
#        year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 28259  2013     10    2     951.0            1000       -9.0    1438.0
# 30229  2013     10    4     954.0            1000       -6.0    1438.0
# 31157  2013     10    5    1002.0            1000        2.0    1418.0
# 31850  2013     10    6     958.0            1000       -2.0    1415.0
# 32842  2013     10    7     957.0            1000       -3.0    1504.0
#
#        sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 28259            1450      -12.0      HA      51  N381HA    JFK  HNL
# 30229            1450      -12.0      HA      51  N380HA    JFK  HNL
# 31157            1450      -32.0      HA      51  N384HA    JFK  HNL
# 31850            1450      -35.0      HA      51  N389HA    JFK  HNL
# 32842            1450       14.0      HA      51  N390HA    JFK  HNL
#
#        air_time  distance  hour  minute            time_hour
# 28259     623.0      4983    10       0  2013-10-02 10:00:00
# 30229     618.0      4983    10       0  2013-10-04 10:00:00
# 31157     593.0      4983    10       0  2013-10-05 10:00:00
# 31850     601.0      4983    10       0  2013-10-06 10:00:00
# 32842     642.0      4983    10       0  2013-10-07 10:00:00

# %%
(flight_data >>
 mutate(
  new_distance = X.distance / 1000,
  carrier_origin = X.carrier + X.origin) >>
 head())
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier       ...        tailnum origin dest  \
# 0             819       11.0      UA       ...         N14228    EWR  IAH
# 1             830       20.0      UA       ...         N24211    LGA  IAH
# 2             850       33.0      AA       ...         N619AA    JFK  MIA
# 3            1022      -18.0      B6       ...         N804JB    JFK  BQN
# 4             837      -25.0      DL       ...         N668DN    LGA  ATL
#
#   air_time  distance  hour  minute            time_hour new_distance  \
# 0    227.0      1400     5      15  2013-01-01 05:00:00        1.400
# 1    227.0      1416     5      29  2013-01-01 05:00:00        1.416
# 2    160.0      1089     5      40  2013-01-01 05:00:00        1.089
# 3    183.0      1576     5      45  2013-01-01 05:00:00        1.576
# 4    116.0       762     6       0  2013-01-01 06:00:00        0.762
#
#    carrier_origin
# 0           UAEWR
# 1           UALGA
# 2           AAJFK
# 3           B6JFK
# 4           DLLGA
#
# [5 rows x 21 columns]

# %%
(flight_data >>
 group_by(X.origin)
)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# 5       2013      1    1     554.0             558       -4.0     740.0
# 6       2013      1    1     555.0             600       -5.0     913.0
# 7       2013      1    1     557.0             600       -3.0     709.0
# 8       2013      1    1     557.0             600       -3.0     838.0
# 9       2013      1    1     558.0             600       -2.0     753.0
# 10      2013      1    1     558.0             600       -2.0     849.0
# 11      2013      1    1     558.0             600       -2.0     853.0
# 12      2013      1    1     558.0             600       -2.0     924.0
# 13      2013      1    1     558.0             600       -2.0     923.0
# 14      2013      1    1     559.0             600       -1.0     941.0
# 15      2013      1    1     559.0             559        0.0     702.0
# 16      2013      1    1     559.0             600       -1.0     854.0
# 17      2013      1    1     600.0             600        0.0     851.0
# 18      2013      1    1     600.0             600        0.0     837.0
# 19      2013      1    1     601.0             600        1.0     844.0
# 20      2013      1    1     602.0             610       -8.0     812.0
# 21      2013      1    1     602.0             605       -3.0     821.0
# 22      2013      1    1     606.0             610       -4.0     858.0
# 23      2013      1    1     606.0             610       -4.0     837.0
# 24      2013      1    1     607.0             607        0.0     858.0
# 25      2013      1    1     608.0             600        8.0     807.0
# 26      2013      1    1     611.0             600       11.0     945.0
# 27      2013      1    1     613.0             610        3.0     925.0
# 28      2013      1    1     615.0             615        0.0    1039.0
# 29      2013      1    1     615.0             615        0.0     833.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336746  2013      9   30    2123.0            2125       -2.0    2223.0
# 336747  2013      9   30    2127.0            2129       -2.0    2314.0
# 336748  2013      9   30    2128.0            2130       -2.0    2328.0
# 336749  2013      9   30    2129.0            2059       30.0    2230.0
# 336750  2013      9   30    2131.0            2140       -9.0    2225.0
# 336751  2013      9   30    2140.0            2140        0.0      10.0
# 336752  2013      9   30    2142.0            2129       13.0    2250.0
# 336753  2013      9   30    2145.0            2145        0.0     115.0
# 336754  2013      9   30    2147.0            2137       10.0      30.0
# 336755  2013      9   30    2149.0            2156       -7.0    2245.0
# 336756  2013      9   30    2150.0            2159       -9.0    2250.0
# 336757  2013      9   30    2159.0            1845      194.0    2344.0
# 336758  2013      9   30    2203.0            2205       -2.0    2339.0
# 336759  2013      9   30    2207.0            2140       27.0    2257.0
# 336760  2013      9   30    2211.0            2059       72.0    2339.0
# 336761  2013      9   30    2231.0            2245      -14.0    2335.0
# 336762  2013      9   30    2233.0            2113       80.0     112.0
# 336763  2013      9   30    2235.0            2001      154.0      59.0
# 336764  2013      9   30    2237.0            2245       -8.0    2345.0
# 336765  2013      9   30    2240.0            2245       -5.0    2334.0
# 336766  2013      9   30    2240.0            2250      -10.0    2347.0
# 336767  2013      9   30    2241.0            2246       -5.0    2345.0
# 336768  2013      9   30    2307.0            2255       12.0    2359.0
# 336769  2013      9   30    2349.0            2359      -10.0     325.0
# 336770  2013      9   30       NaN            1842        NaN       NaN
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819       11.0      UA    1545  N14228    EWR  IAH
# 1                  830       20.0      UA    1714  N24211    LGA  IAH
# 2                  850       33.0      AA    1141  N619AA    JFK  MIA
# 3                 1022      -18.0      B6     725  N804JB    JFK  BQN
# 4                  837      -25.0      DL     461  N668DN    LGA  ATL
# 5                  728       12.0      UA    1696  N39463    EWR  ORD
# 6                  854       19.0      B6     507  N516JB    EWR  FLL
# 7                  723      -14.0      EV    5708  N829AS    LGA  IAD
# 8                  846       -8.0      B6      79  N593JB    JFK  MCO
# 9                  745        8.0      AA     301  N3ALAA    LGA  ORD
# 10                 851       -2.0      B6      49  N793JB    JFK  PBI
# 11                 856       -3.0      B6      71  N657JB    JFK  TPA
# 12                 917        7.0      UA     194  N29129    JFK  LAX
# 13                 937      -14.0      UA    1124  N53441    EWR  SFO
# 14                 910       31.0      AA     707  N3DUAA    LGA  DFW
# 15                 706       -4.0      B6    1806  N708JB    JFK  BOS
# 16                 902       -8.0      UA    1187  N76515    EWR  LAS
# 17                 858       -7.0      B6     371  N595JB    LGA  FLL
# 18                 825       12.0      MQ    4650  N542MQ    LGA  ATL
# 19                 850       -6.0      B6     343  N644JB    EWR  PBI
# 20                 820       -8.0      DL    1919  N971DL    LGA  MSP
# 21                 805       16.0      MQ    4401  N730MQ    LGA  DTW
# 22                 910      -12.0      AA    1895  N633AA    EWR  MIA
# 23                 845       -8.0      DL    1743  N3739P    JFK  ATL
# 24                 915      -17.0      UA    1077  N53442    EWR  MIA
# 25                 735       32.0      MQ    3768  N9EAMQ    EWR  ORD
# 26                 931       14.0      UA     303  N532UA    JFK  SFO
# 27                 921        4.0      B6     135  N635JB    JFK  RSW
# 28                1100      -21.0      B6     709  N794JB    JFK  SJU
# 29                 842       -9.0      DL     575  N326NB    EWR  ATL
# ...                ...        ...     ...     ...     ...    ...  ...
# 336746            2247      -24.0      EV    5489  N712EV    LGA  CHO
# 336747            2323       -9.0      EV    3833  N16546    EWR  CLT
# 336748            2359      -31.0      B6      97  N807JB    JFK  DEN
# 336749            2232       -2.0      EV    5048  N751EV    LGA  RIC
# 336750            2255      -30.0      MQ    3621  N807MQ    JFK  DCA
# 336751              40      -30.0      AA     185  N335AA    JFK  LAX
# 336752            2239       11.0      EV    4509  N12957    EWR  PWM
# 336753             140      -25.0      B6    1103  N633JB    JFK  SJU
# 336754              27        3.0      B6    1371  N627JB    LGA  FLL
# 336755            2308      -23.0      UA     523  N813UA    EWR  BOS
# 336756            2306      -16.0      EV    3842  N10575    EWR  MHT
# 336757            2030      194.0      9E    3320  N906XJ    JFK  BUF
# 336758            2331        8.0      EV    5311  N722EV    LGA  BGR
# 336759            2250        7.0      MQ    3660  N532MQ    LGA  BNA
# 336760            2242       57.0      EV    4672  N12145    EWR  STL
# 336761            2356      -21.0      B6     108  N193JB    JFK  PWM
# 336762              30       42.0      UA     471  N578UA    EWR  SFO
# 336763            2249      130.0      B6    1083  N804JB    JFK  MCO
# 336764            2353       -8.0      B6     234  N318JB    JFK  BTV
# 336765            2351      -17.0      B6    1816  N354JB    JFK  SYR
# 336766               7      -20.0      B6    2002  N281JB    JFK  BUF
# 336767               1      -16.0      B6     486  N346JB    JFK  ROC
# 336768            2358        1.0      B6     718  N565JB    JFK  BOS
# 336769             350      -25.0      B6     745  N516JB    JFK  PSE
# 336770            2019        NaN      EV    5274  N740EV    LGA  BNA
# 336771            1634        NaN      9E    3393     NaN    JFK  DCA
# 336772            2312        NaN      9E    3525     NaN    LGA  SYR
# 336773            1330        NaN      MQ    3461  N535MQ    LGA  BNA
# 336774            1344        NaN      MQ    3572  N511MQ    LGA  CLE
# 336775            1020        NaN      MQ    3531  N839MQ    LGA  RDU
#
#         air_time  distance  hour  minute            time_hour
# 0          227.0      1400     5      15  2013-01-01 05:00:00
# 1          227.0      1416     5      29  2013-01-01 05:00:00
# 2          160.0      1089     5      40  2013-01-01 05:00:00
# 3          183.0      1576     5      45  2013-01-01 05:00:00
# 4          116.0       762     6       0  2013-01-01 06:00:00
# 5          150.0       719     5      58  2013-01-01 05:00:00
# 6          158.0      1065     6       0  2013-01-01 06:00:00
# 7           53.0       229     6       0  2013-01-01 06:00:00
# 8          140.0       944     6       0  2013-01-01 06:00:00
# 9          138.0       733     6       0  2013-01-01 06:00:00
# 10         149.0      1028     6       0  2013-01-01 06:00:00
# 11         158.0      1005     6       0  2013-01-01 06:00:00
# 12         345.0      2475     6       0  2013-01-01 06:00:00
# 13         361.0      2565     6       0  2013-01-01 06:00:00
# 14         257.0      1389     6       0  2013-01-01 06:00:00
# 15          44.0       187     5      59  2013-01-01 05:00:00
# 16         337.0      2227     6       0  2013-01-01 06:00:00
# 17         152.0      1076     6       0  2013-01-01 06:00:00
# 18         134.0       762     6       0  2013-01-01 06:00:00
# 19         147.0      1023     6       0  2013-01-01 06:00:00
# 20         170.0      1020     6      10  2013-01-01 06:00:00
# 21         105.0       502     6       5  2013-01-01 06:00:00
# 22         152.0      1085     6      10  2013-01-01 06:00:00
# 23         128.0       760     6      10  2013-01-01 06:00:00
# 24         157.0      1085     6       7  2013-01-01 06:00:00
# 25         139.0       719     6       0  2013-01-01 06:00:00
# 26         366.0      2586     6       0  2013-01-01 06:00:00
# 27         175.0      1074     6      10  2013-01-01 06:00:00
# 28         182.0      1598     6      15  2013-01-01 06:00:00
# 29         120.0       746     6      15  2013-01-01 06:00:00
# ...          ...       ...   ...     ...                  ...
# 336746      45.0       305    21      25  2013-09-30 21:00:00
# 336747      72.0       529    21      29  2013-09-30 21:00:00
# 336748     213.0      1626    21      30  2013-09-30 21:00:00
# 336749      45.0       292    20      59  2013-09-30 20:00:00
# 336750      36.0       213    21      40  2013-09-30 21:00:00
# 336751     298.0      2475    21      40  2013-09-30 21:00:00
# 336752      47.0       284    21      29  2013-09-30 21:00:00
# 336753     192.0      1598    21      45  2013-09-30 21:00:00
# 336754     139.0      1076    21      37  2013-09-30 21:00:00
# 336755      37.0       200    21      56  2013-09-30 21:00:00
# 336756      39.0       209    21      59  2013-09-30 21:00:00
# 336757      50.0       301    18      45  2013-09-30 18:00:00
# 336758      61.0       378    22       5  2013-09-30 22:00:00
# 336759      97.0       764    21      40  2013-09-30 21:00:00
# 336760     120.0       872    20      59  2013-09-30 20:00:00
# 336761      48.0       273    22      45  2013-09-30 22:00:00
# 336762     318.0      2565    21      13  2013-09-30 21:00:00
# 336763     123.0       944    20       1  2013-09-30 20:00:00
# 336764      43.0       266    22      45  2013-09-30 22:00:00
# 336765      41.0       209    22      45  2013-09-30 22:00:00
# 336766      52.0       301    22      50  2013-09-30 22:00:00
# 336767      47.0       264    22      46  2013-09-30 22:00:00
# 336768      33.0       187    22      55  2013-09-30 22:00:00
# 336769     196.0      1617    23      59  2013-09-30 23:00:00
# 336770       NaN       764    18      42  2013-09-30 18:00:00
# 336771       NaN       213    14      55  2013-09-30 14:00:00
# 336772       NaN       198    22       0  2013-09-30 22:00:00
# 336773       NaN       764    12      10  2013-09-30 12:00:00
# 336774       NaN       419    11      59  2013-09-30 11:00:00
# 336775       NaN       431     8      40  2013-09-30 08:00:00
#
# [336776 rows x 19 columns]

# %%
(flight_data >>
 group_by(X.origin) >>
 summarize(mean_distance = X.distance.mean())
)
# Out:
#   origin  mean_distance
# 0    EWR    1056.742790
# 1    JFK    1266.249077
# 2    LGA     779.835671

# %% [markdown]
# # Bringing it together with pipes

# %% [markdown]
# [Step 1]: Filter out all flights less than 10 hours
# [Step 2]: Create a new column, speed, using the formula [distance / (air time * 60)]
# [Step 3]: Calculate the mean speed for flights originating from each airport
# [Step 4]: Sort the result by mean speed in descending order

# %%
(flight_data >>
  mask(X.hour > 10) >> # step 1
  mutate(speed = X.distance / (X.air_time * 60)) >> # step 2
  group_by(X.origin) >> # step 3a
  summarize(mean_speed = X.speed.mean()) >> # step 3b
  arrange(X.mean_speed, ascending=False) # step 4
)
# Out:
#   origin  mean_speed
# 0    EWR    0.109777
# 1    JFK    0.109427
# 2    LGA    0.107362

# %%
flight_data.loc[flight_data['hour'] > 10, 'speed'] = flight_data['distance'] / (flight_data['air_time'] * 60)
result = flight_data.groupby('origin', as_index=False)['speed'].mean()
result.sort_values('speed', ascending=False)
# Out:
#   origin     speed
# 0    EWR  0.109777
# 1    JFK  0.109427
# 2    LGA  0.107362

# %% [markdown]
# # Union and Union all

# %%
#Create a DataFrame
df1 = {
    'Subject':['semester1','semester2','semester3','semester4','semester1',
               'semester2','semester3'],
   'Score':[62,47,55,74,31,77,85]}
 
df2 = {
    'Subject':['semester1','semester2','semester3','semester4'],
   'Score':[90,47,85,74]}
 
 
df1 = pd.DataFrame(df1,columns=['Subject','Score'])
df2 = pd.DataFrame(df2,columns=['Subject','Score'])

# %%
df1
# Out:
#      Subject  Score
# 0  semester1     62
# 1  semester2     47
# 2  semester3     55
# 3  semester4     74
# 4  semester1     31
# 5  semester2     77
# 6  semester3     85

# %%
df2
# Out:
#      Subject  Score
# 0  semester1     90
# 1  semester2     47
# 2  semester3     85
# 3  semester4     74

# %%
""" Union all in pandas"""
df_union_all= pd.concat([df1, df2])
print(df_union_all)
# Out:
#      Subject  Score
# 0  semester1     62
# 1  semester2     47
# 2  semester3     55
# 3  semester4     74
# 4  semester1     31
# 5  semester2     77
# 6  semester3     85
# 0  semester1     90
# 1  semester2     47
# 2  semester3     85
# 3  semester4     74

# %%
""" union in pandas"""
df_union= pd.concat([df1, df2]).drop_duplicates()
print(df_union)
# Out:
#      Subject  Score
# 0  semester1     62
# 1  semester2     47
# 2  semester3     55
# 3  semester4     74
# 4  semester1     31
# 5  semester2     77
# 6  semester3     85
# 0  semester1     90

# %%
import pandas as pd

df1 = pd.DataFrame({'time': [35427889701, 35427909854, 35427929709,35427949712, 35428009860], 

                    'velocity_x':[12.5451, 12.5401,12.5351,12.5401,12.5251],

                   'yaw' : [-0.0787806, -0.0784749, -0.0794889,-0.0795915,-0.0795472]})

df2 = pd.DataFrame({'time': [35427929709, 35427949712, 35427009860,35427029728, 35427049705], 

                    'velocity':[12.6583, 12.6556,12.6556,12.6556,12.6444],

                    'yawrate' : [-0.0750492, -0.0750492, -0.074351,-0.074351,-0.074351]})

df3 = pd.DataFrame(columns=['time','velocity_x','yaw','velocity','yawrate'])

# %%
df1
# Out:
#           time  velocity_x       yaw
# 0  35427889701     12.5451 -0.078781
# 1  35427909854     12.5401 -0.078475
# 2  35427929709     12.5351 -0.079489
# 3  35427949712     12.5401 -0.079591
# 4  35428009860     12.5251 -0.079547

# %%
df2
# Out:
#           time  velocity   yawrate
# 0  35427929709   12.6583 -0.075049
# 1  35427949712   12.6556 -0.075049
# 2  35427009860   12.6556 -0.074351
# 3  35427029728   12.6556 -0.074351
# 4  35427049705   12.6444 -0.074351

# %%
df3
# Out:
# Empty DataFrame
# Columns: [time, velocity_x, yaw, velocity, yawrate]
# Index: []

# %%
for index, row in df1.iterrows():

    min=100000

    for indexer, rows in df2.iterrows():

        if abs(float(row['time'])-float(rows['time']))<min:

            min = abs(float(row['time'])-float(rows['time']))

            #storing the position 

            pos = indexer

    df3.loc[index,'time'] = df1['time'][pos]

    df3.loc[index,'velocity_x'] = df1['velocity_x'][pos]

    df3.loc[index,'yaw'] = df1['yaw'][pos]

    df3.loc[index,'velocity'] = df2['velocity'][pos]

    df3.loc[index,'yawrate'] = df2['yawrate'][pos]

# %%
df3
# Out:
#           time velocity_x        yaw velocity    yawrate
# 0  35427889701    12.5451 -0.0787806  12.6583 -0.0750492
# 1  35427889701    12.5451 -0.0787806  12.6583 -0.0750492
# 2  35427889701    12.5451 -0.0787806  12.6583 -0.0750492
# 3  35427909854    12.5401 -0.0784749  12.6556 -0.0750492
# 4  35427909854    12.5401 -0.0784749  12.6556 -0.0750492

# %%
df1['key'] = 1

df2['key'] = 1

df1.rename(index=str, columns ={'time' : 'time_x'}, inplace=True)

df = df2.merge(df1, on='key', how ='left').reset_index()

df['diff'] = df.apply(lambda x: abs(x['time']  - x['time_x']), axis=1)

df.sort_values(by=['time', 'diff'], inplace=True)

df=df.groupby(['time']).first().reset_index()[['time', 'velocity_x', 'yaw', 'velocity', 'yawrate']]

# %%
df
# Out:
#           time  velocity_x       yaw  velocity   yawrate
# 0  35427009860     12.5451 -0.078781   12.6556 -0.074351
# 1  35427029728     12.5451 -0.078781   12.6556 -0.074351
# 2  35427049705     12.5451 -0.078781   12.6444 -0.074351
# 3  35427929709     12.5351 -0.079489   12.6583 -0.075049
# 4  35427949712     12.5401 -0.079591   12.6556 -0.075049
